# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

# %%
len(STOP_WORDS)
# Out:
# 326

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("we just open our wings , the flaying part is coming soon")

# for token in doc:
#     if token.is_stop:
#         # print(token.text)
#         print(token)

[token for token in doc if token.is_stop]
[token.text for token in doc if token.is_stop]
# Out:
# ['we', 'just', 'our', 'the', 'part', 'is']

# %%
def preprocess(text):
    doc = nlp(text)
    # no_stop_words = []
    no_stop_words = [token.text for token in doc if not token.is_stop and not token.is_punct] 
    # for token in doc:
    #     if not token.is_stop and token.is_punct:  //same
    #         no_stop_words.append(token)
    # return no_stop_words
    return " ".join(no_stop_words) #convert it into string

# %%
preprocess(doc)
# Out:
# 'open wings flaying coming soon'

# %%
preprocess("The other is not other but your divine brother")
# Out:
# ['divine', 'brother']

# %%
import pandas as pd

df = pd.read_json('combined.json' , lines=True)
df.head()
# Out:
#             id                                              title  \
# 0         None       Convicted Bomb Plotter Sentenced to 30 Years
# 1      12-919   $1 Million in Restitution Payments Announced t...
# 2      11-1002  $1 Million Settlement Reached for Natural Reso...
# 3       10-015  10 Las Vegas Men Indicted \r\nfor Falsifying V...
# 4       18-898  $100 Million Settlement Will Speed Cleanup Wor...
# ...        ...                                                ...
# 13082   16-735  Yuengling to Upgrade Environmental Measures to...
# 13083   10-473  Zarein Ahmedzay Pleads Guilty to Terror Violat...
# 13084   17-045  Zimmer Biomet Holdings Inc. Agrees to Pay $17....
# 13085   17-252  ZTE Corporation Agrees to Plead Guilty and Pay...
# 13086   17-304  ZTE Corporation Pleads Guilty for  Violating U...
#
#                                                 contents  \
# 0      PORTLAND, Oregon. – Mohamed Osman Mohamud, 23,...
# ...

# %%
df = df[df['topics'].str.len()!=0]
df.head()
# Out:
#             id                                              title  \
# 4       18-898  $100 Million Settlement Will Speed Cleanup Wor...
# 7      14-1412  14 Indicted in Connection with New England Com...
# 19     17-1419  2017 Southeast Regional Animal Cruelty Prosecu...
# 22     15-1562  21st Century Oncology to Pay $19.75 Million to...
# 23     17-1404  21st Century Oncology to Pay $26 Million to Se...
# ...        ...                                                ...
# 13081  14-1377  Yuba City, California, Man Sentenced to 46 Mon...
# 13082   16-735  Yuengling to Upgrade Environmental Measures to...
# 13084   17-045  Zimmer Biomet Holdings Inc. Agrees to Pay $17....
# 13085   17-252  ZTE Corporation Agrees to Plead Guilty and Pay...
# 13086   17-304  ZTE Corporation Pleads Guilty for  Violating U...
#
#                                                 contents  \
# 4      The U.S. Department of Justice, the U.S. Envir...
# ...

# %%
df = df.head(100)
df.shape
# Out:
# (100, 6)

# %%
df['contents_new'] = df["contents"].apply(preprocess)

# %%
df.head()
# Out:
#           id                                              title  \
# 4     18-898  $100 Million Settlement Will Speed Cleanup Wor...
# 7    14-1412  14 Indicted in Connection with New England Com...
# 19   17-1419  2017 Southeast Regional Animal Cruelty Prosecu...
# 22   15-1562  21st Century Oncology to Pay $19.75 Million to...
# 23   17-1404  21st Century Oncology to Pay $26 Million to Se...
# ..       ...                                                ...
# 316  15-1359  Alaska Plastic Surgeon Convicted of Wire Fraud...
# 318   16-396  Alaska Plastic Surgeon Sentenced to Prison for...
# 321   17-736  Alaskan Commercial Fishing Couple Charged with...
# 322   18-717  Alaskan Husband And Wife Plead Guilty To Willf...
# 324  16-1345        Alaskan Oncologist Indicted for Tax Evasion
#
#                                               contents  \
# 4    The U.S. Department of Justice, the U.S. Envir...
# 7    A 131-count criminal indictment was unsealed t...
# ...

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp('hey i miss and you, know how much i love you')

# %%
doc = nlp("we just open our wings , the flaying part is coming soon")

# %%
no_stop =[]
for token in doc:
    if not token.is_stop and not token.is_punct:
        no_stop.append(token.text)
no_stop
# Out:
# ['open', 'wings', 'flaying', 'coming', 'soon']

# %%
def preprocess(text):
    no_stop_word =[]
    doc = nlp(text)
    for token in doc:
        if not token.is_stop and not token.is_punct:
            no_stop_word.append(token.text)
    return " ".join(no_stop_word)

# %%
preprocess('we just open our wings , the flaying part is coming soon')
# Out:
# 'open wings flaying coming soon'

# %%
import pandas as pd 

df = pd.read_json('combined.json' , lines=True)

# %%
df.head()
# Out:
#         id  ...                                    components
# 0     None  ...            [National Security Division (NSD)]
# 1  12-919   ...  [Environment and Natural Resources Division]
# 2  11-1002  ...  [Environment and Natural Resources Division]
# 3   10-015  ...  [Environment and Natural Resources Division]
# 4   18-898  ...  [Environment and Natural Resources Division]
#
# [5 rows x 6 columns]

# %%
df = df[df['topics'].str.len() != 0]

# %%
df.head()
# Out:
#          id  ...                                         components
# 4    18-898  ...       [Environment and Natural Resources Division]
# 7   14-1412  ...                                   [Civil Division]
# 19  17-1419  ...  [Environment and Natural Resources Division, U...
# 22  15-1562  ...                                   [Civil Division]
# 23  17-1404  ...           [Civil Division, USAO - Florida, Middle]
#
# [5 rows x 6 columns]

# %%
df.topics.value_counts()
# Out:
# [Tax]                                                                        706
# [Consumer Protection]                                                        335
# [Civil Rights]                                                               305
# [Antitrust]                                                                  292
# [Hate Crimes]                                                                246
#                                                                             ...
# [Tax, Health Care Fraud]                                                       1
# [Prescription Drugs, Consumer Protection, Health Care Fraud]                   1
# [Civil Rights, Firearms Offenses]                                              1
# [Antitrust, Financial Fraud, Securities, Commodities, & Investment Fraud]      1
# [Hate Crimes, Civil Rights]                                                    1
# Name: topics, Length: 252, dtype: int64

# %%
df= df.head(100)

# %%
df['contents_new'] = df.contents.apply(preprocess)

# %%
df
# Out:
#           id  ...                                       contents_new
# 4     18-898  ...  U.S. Department Justice U.S. Environmental Pro...
# 7    14-1412  ...  131 count criminal indictment unsealed today B...
# 19   17-1419  ...  United States Attorney Office Middle District ...
# 22   15-1562  ...  21st Century Oncology LLC agreed pay $ 19.75 m...
# 23   17-1404  ...  21st Century Oncology Inc. certain subsidiarie...
# ..       ...  ...                                                ...
# 316  15-1359  ...  Doctor Hid Millions Secret Accounts Panama Ala...
# 318   16-396  ...  Defendant Concealed Bank Accounts Panama Costa...
# 321   17-736  ...  Alaskan couple charged federal court Juneau Al...
# 322   18-717  ...  husband wife pleaded guilty yesterday counts w...
# 324  16-1345  ...  resident Big Lake Alaska indicted counts tax e...
#
# [100 rows x 7 columns]
